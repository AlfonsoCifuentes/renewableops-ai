# %% [markdown]
# # Weather EDA
# Inspect weather regimes without using future values as model features.

# %%
import pandas as pd
frame = pd.read_parquet('../data/lakehouse/silver/generation.parquet')
frame[['irradiance_wm2','wind_speed_ms','temperature_c','cloud_cover_fraction']].describe(percentiles=[.01,.5,.99])
