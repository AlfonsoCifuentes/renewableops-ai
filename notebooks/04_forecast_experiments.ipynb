# %% [markdown]
# # Forecast experiments
# Review immutable candidate metrics. Production training belongs in the pipeline, not the notebook.

# %%
import pandas as pd
metrics = pd.read_json('../data/models/forecast_metrics.json')
metrics.sort_values(['technology','mae_mw'])
