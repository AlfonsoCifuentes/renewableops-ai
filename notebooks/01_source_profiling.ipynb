# %% [markdown]
# # Source profiling
# Review registry metadata and bounded official-source responses. Never persist credentials.

# %%
from pathlib import Path
import yaml
registry = yaml.safe_load(Path('../data/source_registry.yaml').read_text())
[(row['source_id'], row['authority'], row['enabled']) for row in registry['sources']]
