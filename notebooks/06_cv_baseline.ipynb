# %% [markdown]
# # Classical CV baseline
# HOG, LBP and texture statistics on synthetic inspection patterns.

# %%
import json
from pathlib import Path
json.loads(Path('../data/models/cv_metrics.json').read_text())
