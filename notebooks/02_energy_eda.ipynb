# %% [markdown]
# # Energy EDA
# Portfolio distributions, missingness and physical bounds from the versioned Silver sample.

# %%
import pandas as pd
frame = pd.read_parquet('../data/lakehouse/silver/generation.parquet')
frame.groupby('technology').agg(rows=('asset_id','size'), assets=('asset_id','nunique'), mean_mw=('power_mw','mean'))
