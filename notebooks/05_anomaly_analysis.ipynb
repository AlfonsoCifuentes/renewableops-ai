# %% [markdown]
# # Anomaly analysis
# Inspect causal evidence, labelled synthetic failures and severity.

# %%
import pandas as pd
from renewableops.anomalies import detect_anomalies
frame = pd.read_parquet('../data/lakehouse/silver/generation.parquet')
detect_anomalies(frame).groupby(['severity','labelled_cause']).size()
