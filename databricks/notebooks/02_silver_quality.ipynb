# %% [markdown]
# # 02 · Silver quality
# Review expectations, quarantine and unique asset-hour keys.

# %%
display(spark.sql('SELECT quality_flag, count(*) rows FROM renewableops.dev.silver_generation GROUP BY quality_flag'))
