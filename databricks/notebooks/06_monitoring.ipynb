# %% [markdown]
# # 06 · Monitoring
# Query Lakeflow event evidence and Gold freshness.

# %%
display(spark.sql('SELECT max(date_hour) latest_hour, count(*) rows FROM renewableops.dev.gold_portfolio_hourly'))
