# %% [markdown]
# # 04 · sklearn training
# The production-like implementation is `src/renewableops_databricks/train_register.py`; this notebook is an inspection surface.

# %%
training = spark.table('renewableops.dev.silver_generation').where("technology in ('solar','wind')").limit(50000).toPandas()
training.shape
