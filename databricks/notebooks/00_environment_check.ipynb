# %% [markdown]
# # 00 · Environment check
# Confirm serverless, Unity Catalog, runtime, current user and active namespace.

# %%
spark.sql('SELECT current_user(), current_catalog(), current_schema()').show(truncate=False)
print(spark.version)
