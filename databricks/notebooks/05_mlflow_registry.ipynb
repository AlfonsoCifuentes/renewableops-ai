# %% [markdown]
# # 05 · MLflow registry
# Inspect versions and aliases; promotion remains an explicit approval action.

# %%
import mlflow
mlflow.set_registry_uri('databricks-uc')
mlflow.MlflowClient().search_model_versions("name='renewableops.dev.renewable_forecast'")
