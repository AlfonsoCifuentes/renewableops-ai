# %% [markdown]
# # 01 · Upload and Bronze
# Verify the bounded Parquet sample already uploaded to the governed landing Volume.

# %%
display(dbutils.fs.ls('/Volumes/renewableops/dev/landing/scada'))
