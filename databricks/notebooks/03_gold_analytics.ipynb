# %% [markdown]
# # 03 · Gold analytics
# Inspect the governed technology-hour mart used by AI/BI.

# %%
display(spark.table('renewableops.dev.gold_portfolio_hourly').orderBy('date_hour', ascending=False).limit(48))
